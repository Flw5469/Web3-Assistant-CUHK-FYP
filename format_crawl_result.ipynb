# %%
import os
import json

def read_json_from_directory(directory):
    json_data = []
    
    # Iterate through all files in the specified directory
    for filename in os.listdir(directory):
        if filename.endswith('.json'):  # Check if the file is a JSON file
            file_path = os.path.join(directory, filename)  # Get the full file path
            with open(file_path, 'r', encoding="utf-8") as file:
                try:
                    data = json.load(file)  # Load JSON data
                    json_data.append(data)  # Append the data to the list
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON from {filename}: {e}")
    return json_data

directory_path = 'crawl_result'  # Replace with your directory path
all_json_data = read_json_from_directory(directory_path)

# %%
result = []
for data in all_json_data:
  if data!= []:
   result += data

for data in result:
    if data["news_title"]==None:
        data["news_title"] = ""
    if data["news_content"]==None:
        data["news_content"] = ""

    if "links" in data:
      del data['links']

all_coins = {
  "bitcoin":"Bitcoin", 
  "Cardano":"Cardano",
  "ethereum":"Ethereum", 
  "Tron":"Tron", 
  "Dogecoin":"Dogecoin",
  "Market" : "Market",
  "Crypto" : "Crypto",
}
for data in result:
    coin = []
    for ele in all_coins:
        if ele.lower() in data['news_content'].lower():
            coin.append(all_coins[ele])
    data['coins_name'] = coin
    data['news_content'] = data['news_content'].replace("|", " ")

filtered_result = [data for data in result if data['coins_name']!=[]]
print(filtered_result[1])
# Out:
# {'URL': 'https://www.wired.com/story/user-owned-ai-illia-polosukhin-open-source-web3/', 'news_title': 'He Helped Invent Generative AI. Now He Wants to Save It | WIRED', 'news_content': "To revisit this article, visit My Profile, thenView saved stories. In 2016, Google engineer Illia Polosukhin had lunch with a colleague, Jacob Uszkoreit. Polosukhin had been frustrated by a lack of progress in his project, using AI to provide useful answers to questions posed by users, and Uszkoreit suggested he try a technique he had been brainstorming that he called self-attention. Thus began an 8-person collaboration that ultimately resulted in a 2017 paper called “Attention Is All You Need,” whichintroduced the concept of transformersas a way to supercharge artificial intelligence. It changed the world. Eight years later, though, Polosukhin is not completely happy with the way things are shaking out. A big believer in open source, he’s concerned about the secretive nature of transformer-based larg
# ...

# %%
import pandas as pd

def write_json_array_to_csv(json_array, filename):
    # Convert the array of JSON objects to a DataFrame
    df = pd.DataFrame(json_array)

    # Save the DataFrame to a CSV file
    df.to_csv(filename, index=False, sep="|")

write_json_array_to_csv(filtered_result,"formatted_result.csv")

# %%
print(result[170])
# Out:
# {'URL': 'https://www.euronews.com/programs/spotlight', 'news_title': 'Spotlight - Latest episodes, latest news and updates about | Euronews', 'news_content': "Radio Schuman This is Radio Schuman, your new go-to podcast to spice up your weekday mornings with relevant news, insights, and behind-the-scenes from Brussels and beyond. No Comment No agenda, no argument, no bias, No Comment.\xa0Get the story without commentary. My Wildest Prediction Dare to imagine the future with business and tech visionaries The Big Question Deep dive conversations with business leaders Euronews Tech Talks Euronews Tech Talks goes beyond discussions to explore the impact of new technologies on our lives. With explanations, engaging Q&As, and lively conversations, the podcast provides valuable insights into the intersection of technology and society. Water Matters Europe's water is under increasing pressure. Pollution, droughts, floods are taking their toll on our drinking water, lakes, rivers and coastline
# ...

# %%
for data in result:
  print(data['coins_name'])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['bitcoin']
# ['Tron']
# ['bitcoin']
# []
# ['bitcoin', 'ethereum']
# []
# ['bitcoin']
# []
# ['ethereum']
# ['Tron']
# ['bitcoin', 'Tron']
# []
# []
# ['bitcoin', 'ethereum', 'Tron']
# ['bitcoin', 'ethereum']
# ['bitcoin', 'ethereum']
# []
# ['bitcoin', 'ethereum', 'Tron']
# ['bitcoin', 'ethereum', 'Tron']
# []
# ['Tron']
# ['ethereum']
# ['bitcoin']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Tron']
# ['Tron']
# []
# ['Tron']
# ['Tron']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['bitcoin', 'Tron']
# []
# ['bitcoin', 'ethereum']
# ['bitcoin', 'ethereum', 'Tron', 'Dogecoin']
# ['bitcoin', 'ethereum', 'Tron']
# ['bitcoin', 'Cardano', 'Tron']
# ['bitcoin']
# ['bitcoin']
# ['bitcoin', 'Tron']
# ['bitcoin']
# ['bitcoin', 'ethereum']
# ['bitcoin']
# ['bitcoin', 'Cardano', 'ethereum', 'Tron']
# ['bitcoin']
# ['bitcoin']
# ['bitcoin', 'ethereum', 'Tron']
# ['bitcoin']
# ['bitcoin']
# ...
